# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\ilfra\\Desktop\\progetti Aesys\\model_selection\\Dataset\\raw\\housing.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('C:\\Users\\ilfra\\Desktop\\progetti Aesys\\model_selection\\Dataset\\raw\\housing.csv')
#
# File c:\Users\ilfra\venv_global\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# solo total bedrooms ha molti valori nan che vedremo se sistemare con mediani o simili

# %%
df['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity           str
# dtype: object

# %% [markdown]
# ocean proximity va cambiato e trasformato in un tipo non object

# %%
df['ocean_proximity'].head(10)
# Out:
# 0    NEAR BAY
# 1    NEAR BAY
# 2    NEAR BAY
# 3    NEAR BAY
# 4    NEAR BAY
# 5    NEAR BAY
# 6    NEAR BAY
# 7    NEAR BAY
# 8    NEAR BAY
# 9    NEAR BAY
# Name: ocean_proximity, dtype: str

# %%
df['ocean_proximity'].tail(10)
# Out:
# 20630    INLAND
# 20631    INLAND
# 20632    INLAND
# 20633    INLAND
# 20634    INLAND
# 20635    INLAND
# 20636    INLAND
# 20637    INLAND
# 20638    INLAND
# 20639    INLAND
# Name: ocean_proximity, dtype: str

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# praticamente possiamo separarli molto facilmente con un one hot encoding
